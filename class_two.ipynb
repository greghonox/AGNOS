# %%
from agno.agent import Agent
from dotenv import load_dotenv
from agno.models.ollama import Ollama 
from agno.tools.tavily import TavilyTools
from agno.tools.yfinance import YFinanceTools

# %%
load_dotenv()
# Out:
# True

# %%
llm = Groq()
agent = Agent(
    model=Ollama(id="gemma4:31b-cloud"),
    tools=[TavilyTools(), YFinanceTools()],
    debug_mode=True
)

# %%
agent.print_response("Pesquise aonde fica hortolandia no brasil?")
# Out:
# DEBUG ************** Agent ID: civic-morse-325107b5 **************
# DEBUG Creating new AgentSession: bb61871b-ab02-4efa-87f8-5abc00b9cdf2
# DEBUG ** Agent Run Start: 71b6710e-6ddf-4431-9752-ad30907af65d ***
# DEBUG Processing tools for model
# DEBUG Added tool web_search_using_tavily from tavily_tools
# DEBUG Added tool get_current_stock_price from yfinance_tools
# DEBUG ------------------ Ollama Response Start -------------------
# DEBUG ----------------- Model: gemma4:31b-cloud ------------------
# DEBUG =========================== user ===========================
# DEBUG Pesquise aonde fica hortolandia no brasil?
# DEBUG ======================== assistant =========================
# DEBUG Tool Calls:
#         - ID: '195215e3-9ebe-49a9-812a-3352243acb49'
#           Name: 'web_search_using_tavily'
#           Arguments: 'query: onde fica Hortolândia no Brasil'
# DEBUG ************************  METRICS  *************************
# DEBUG * Tokens:                      input=211, output=27, total=238
# DEBUG * Duration:                    0.9490s
# DEBUG * Tokens per second:           28.4512 tokens/s
# DEBUG * Time to first token:         0.9490s
# DEBUG ************************  METRICS  *************************
# DEBUG Running: web_search_using_tavily(query=...)
# DEBUG =========================== tool ===========================
# DEBUG Tool call Id: 195215e3-9ebe-49a9-812a-3352243acb49
# DEBUG # onde fica Hortolândia no Brasil
#
#       ### Summary
#       Hortolândia is a municipality in the state of São Paulo, Brazil, located in the Metropolitan Region of
#       Campinas, about 110 km northwest of São Paulo city.
#
#       ### [Hortolândia – Wikipédia, a enciclopédia livre](https://pt.wikipedia.org/wiki/Hortol%C3%A2ndia)
#       Hortolândia é um município brasileiro no interior do estado de São Paulo. Localiza-se na Região Metropolitana
#       de Campinas, a noroeste da capital do estado,
#
#       ### [SP, CONHEÇA Hortolândia SÃO PAULO, (OS DADOS ... - YouTube](https://www.youtube.com/watch?v=z1X8ybQOcVw)
#       Hortolândia é um município brasileiro no interior do estado de São Paulo. Pertence à Mesorregião e
#       Microrregião de Campinas, localizando-se
#
#       ### [Hortolândia - Wikipedia](https://en.wikipedia.org/wiki/Hortol%C3%A2ndia)
#       It is located northwest of the state capital, about 110 km away. It is part of the São Paulo macrometropolis,
#       which exceeds 29 million inhabitants and makes up
#
#       ### [Hortolândia - Simple English Wikipedia, the free
#       encyclopedia](https://simple.wikipedia.org/wiki/Hortol%C3%A2ndia)
#       ## Contents
#
#       # Hortolândia
#
#       | Hortolândia | |
#        --- |
#       | Municipality | |
#       | Flag of Hortolândia Flag  Coat of arms of Hortolândia Coat of arms | |
#       | Location in São Paulo state Location in São Paulo state | |
#       | Hortolândia is located in Brazil Hortolândia  Hortolândia  Location in Brazil | |
#       | Coordinates: 22°51′30″S 47°13′12″W﻿ / ﻿22.85833°S 47.22000°W﻿ / -22.85833; -47.22000 | |
#       | Country | Brazil |
#       | Region | Southeast Brazil |
#       | State | São Paulo "São Paulo (state)") |
#       | Metropolitan Region | Campinas") |
#       | Area | |
#       | • Total | 62.42 km2 (24.10 sq mi) |
#       | Elevation | 587 m (1,926 ft) |
#       | Population (2020 ) | |
#       | • Total | 234,259 |
#       | • Density | 3,800/km2 (9,700/sq mi) |
#       | Time zone | UTC-3 (BRT")) |
#       | • Summer (DST) | UTC-2") (BRST")) |
#       | Website | www.hortolandia.sp.gov.br | [...] Flag of Hortolândia
#       Coat of arms of Hortolândia
#       Location in São Paulo state
#       Hortolândia is located in Brazil
#       Hortolândia
#
#       Hortolândia is a municipality in the state of São Paulo "São Paulo (state)") in Brazil. It is part of the
#       Metropolitan Region of Campinas"). 234,259 people lived here in 2020.
#
#       ## References
#
#       Wikimedia Foundation
#       Powered by MediaWiki [...] Wikipedia
#       The Free Encyclopedia
#
#       ## Contents
#
#       # Hortolândia
#
#       ### [Hortolândia - SP, Brazil - Map & Directions - Apple
#       Maps](https://maps.apple.com/place?auid=4461605798393645865)
#       # Apple Maps
#
#       Have a Business on Maps?
#
#       Manage Your Business
#
#       # Hortolndia
#
#       # Hortolndia
#
#       Directions
#
#       POPULATION
#
#       234,259
#
#       ELEVATION
#
#       1,926 ft
#
#       AREA
#
#       24 mi²
#
#       ## About
#
#       Hortolndia is a Brazilian municipality in the interior of the state of São Paulo. It is part of the
#       Metropolitan Region of Campinas and the Mesoregion and Microregion of Campinas. It is located northwest of
#       the state capital, about 110 km away. It is part of the São Paulo macrometropolis, which exceeds 29 million
#       inhabitants and makes up approximately 75 percent of the state's population. The metropolitan regions of
#       Campinas and São Paulo form the first megalopolis in the southern hemisphere.
#
#       MoreLess
#
#       More on Wikipedia
#
#       ## Details
#
#       ### Location
#
#       Hortolndia - SP
#
#       ### Coordinates
#
#       22.87211° S, 47.21384° W
#
#       More on Wikipedia
# DEBUG ======================== assistant =========================
# DEBUG Hortolândia fica no **interior do estado de São Paulo**, Brasil.
#
#       Ela está localizada na **Região Metropolitana de Campinas**, a aproximadamente 110 km de distância da
#       capital, São Paulo.
# DEBUG ************************  METRICS  *************************
# DEBUG * Tokens:                      input=1278, output=49, total=1327
# DEBUG * Duration:                    1.4905s
# DEBUG * Tokens per second:           32.8741 tokens/s
# DEBUG * Time to first token:         1.4905s
# DEBUG ************************  METRICS  *************************
# DEBUG ------------------- Ollama Response End --------------------
# DEBUG Added RunOutput to Agent Session
# DEBUG *** Agent Run End: 71b6710e-6ddf-4431-9752-ad30907af65d ****
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>

# %%
agent.print_response("Quanto vale um carro gm vectra 2011 automatico?")
# Out:
# DEBUG ***** Session ID: bb61871b-ab02-4efa-87f8-5abc00b9cdf2 *****
# DEBUG ************** Agent ID: civic-morse-325107b5 **************
# DEBUG Creating new AgentSession: bb61871b-ab02-4efa-87f8-5abc00b9cdf2
# DEBUG ** Agent Run Start: 972f7427-a40c-4edb-8060-b76593ee3bf5 ***
# DEBUG Processing tools for model
# DEBUG Added tool web_search_using_tavily from tavily_tools
# DEBUG Added tool get_current_stock_price from yfinance_tools
# DEBUG ------------------ Ollama Response Start -------------------
# DEBUG ----------------- Model: gemma4:31b-cloud ------------------
# DEBUG =========================== user ===========================
# DEBUG Quanto vale um carro gm vectra 2011 automatico?
# DEBUG ======================== assistant =========================
# DEBUG Tool Calls:
#         - ID: 'fe83b49f-f38c-474a-8807-2657b2352a8e'
#           Name: 'web_search_using_tavily'
#           Arguments: 'query: preço GM Vectra 2011 automático Tabela FIPE Brasil'
# DEBUG ************************  METRICS  *************************
# DEBUG * Tokens:                      input=215, output=36, total=251
# DEBUG * Duration:                    16.1273s
# DEBUG * Tokens per second:           2.2322 tokens/s
# DEBUG * Time to first token:         16.1273s
# DEBUG ************************  METRICS  *************************
# DEBUG Running: web_search_using_tavily(query=...)
# DEBUG =========================== tool ===========================
# DEBUG Tool call Id: fe83b49f-f38c-474a-8807-2657b2352a8e
# DEBUG # preço GM Vectra 2011 automático Tabela FIPE Brasil
#
#       ### Summary
#       The 2011 Chevrolet Vectra automatic's price according to the FIPE table is R$ 48,596.00 in April 2026. The
#       range for different versions is R$ 36,985 to R$ 45,491. The most complete version is valued at R$ 45,491.
#
#       ### [Tabela FIPE de Chevrolet Vectra COLLECTION 2.0 FlexPower 8V Aut. 2011 Gasolina - Código FIPE
#       004378-8](https://www.tabelafipebrasil.com/carros/GM---CHEVROLET/VECTRA-COLLECTION-20-FLEXPOWER-8V-AUT/2011-G
#       asolina)
#       Tabela FIPE Brasil [...] R$ 48.596,00
#
#       ### Simular financiamento de R$ 48.596,00
#
#       Este é o valor atualizado em Abril de 2026 para carro Chevrolet Vectra 2011 Tabela FIPE.
#
#
#
#       ### O preço do Chevrolet Vectra 2011 pela Tabela FIPE de Abril de 2026 é R$ 48.596,00.
#
#       Tabela FIPE Referência: Abril 2026
#
#       Veja em baixo a desvalorização ou valorização deste veículo.
#
#       Para ver mais modelos de carros Chevrolet, consulte a Tabela FIPE de carros Chevrolet
#
#       Este modelo de carro é uma variante do Chevrolet Vectra.
#
#       Compare o valor de carros Chevrolet Vectra COLLECTION 2.0 FlexPower 8V Aut. com outros veículos e veja as
#       diferenças de valor.
#
#
#
#       Consulte também o Financiamento para Chevrolet Vectra COLLECTION 2.0 FlexPower 8V Aut.
#
#       Veja também a Tabela FIPE carros Chevrolet 2011 completa e atualizada em Abril de 2026. [...] | Mai 2024 | R$
#       45.521,00 | 0,63 % | 4,05 % |
#       | Abr 2024 | R$ 45.235,00 | -3,50 % | 3,40 % |
#       | Mar 2024 | R$ 46.876,00 | 0,93 % | 7,15 % |
#       | Fev 2024 | R$ 46.442,00 | 0,18 % | 6,16 % |
#       | Jan 2024 | R$ 46.358,00 | -2,56 % | 5,97 % |
#       | Dez 2023 | R$ 47.577,00 | -2,21 % | 8,75 % |
#       | Nov 2023 | R$ 48.652,00 | 0,16 % | 11,21 % |
#       | Out 2023 | R$ 48.575,00 | 2,68 % | 11,03 % |
#       | Set 2023 | R$ 47.307,00 | -0,03 % | 8,14 % |
#       | Ago 2023 | R$ 47.322,00 | 3,50 % | 8,17 % |
#       | Jul 2023 | R$ 45.722,00 | 3,50 % | 4,51 % |
#       | Jun 2023 | R$ 44.176,00 | -1,75 % | 0,98 % |
#       | Mai 2023 | R$ 44.962,00 | -2,62 % | 2,77 % |
#       | Abr 2023 | R$ 46.171,00 | 3,19 % | 5,54 % |
#       | Mar 2023 | R$ 44.743,00 | -2,24 % | 2,27 % |
#       | Fev 2023 | R$ 45.766,00 | 3,24 % | 4,61 % |
#       | Jan 2023 | R$ 44.330,00 | 3,50 % | 1,33 % |
#
#       ### [Tabela Fipe Chevrolet Vectra 2011 -
#       Mobiauto](https://www.mobiauto.com.br/tabela-fipe/carros/chevrolet/vectra/2011)
#       Os preços do Vectra 2011, da Chevrolet, variam conforme a versão. Os modelos mais básicos começam a partir de
#       R$ 36.985, esse valor está 3.3% menor em comparação ao mês passado, enquanto as versões mais completas chegam
#       a R$ 45.491 e para o modelo mais completo o valor está 0.27% menor em comparação ao mês passado.
#
#        Os valores da Tabela Fipe são baseados nos preços médios do mercado brasileiro e são atualizados mensalmente
#       no site da Mobiauto. Confira os anúncios do modelo e faça um bom negócio!
#
#       ## Venda seu veículo na Mobiauto com facilidade e rapidez
#
#       Venda seu veículo na Mobiauto com facilidade e rapidez
#
#       Marcas
#
#       Modelos
#
#       Anos
#
#       ## Consulte outros anos do Chevrolet Vectra
#
#       Chevrolet Vectra 2010
#
#       Preços de R$ 36.082 a R$ 40.634
#
#       Chevrolet Vectra 2009 [...] Usar minha localização
#
#       # Tabela Fipe Chevrolet Vectra 2011
#
#       Saiba o valor atualizado do modelo Chevrolet Vectra 2011
#
#       Logo FIPE
#
#       R$ 36.985 a R$ 45.491
#
#       ## Selecione uma versão do Chevrolet Vectra 2011
#
#       | Modelos | Preços |  |
#        ---
#       | Chevrolet Vectra Expression 2.0 (Flex) | R$ 36.985 | Ver ofertas |
#       | Chevrolet Vectra Elegance 2.0 (Flex) | R$ 40.610 | Ver ofertas |
#       | Chevrolet Vectra Expression 2.0 (Flex) (Aut) | R$ 40.428 | Ver ofertas |
#       | Chevrolet Vectra Collection 2.0 Flexpower (Aut) | R$ 45.491 | Ver ofertas |
#       | Chevrolet Vectra Elegance 2.0 (Flex) (Aut) | R$ 41.006 | Ver ofertas |
#       | Chevrolet Vectra Elite 2.0 (Flex) (Aut) | R$ 43.061 | Ver ofertas |
#
#       ### Está pensando em comprar, vender ou financiar um carro? [...] Preços de R$ 13.711 a R$ 17.831
#
#       Chevrolet Vectra 1996
#
#       Preços de R$ 13.208 a R$ 26.320
#
#       Chevrolet Vectra 1995
#
#       Preços de R$ 11.738 a R$ 25.678
#
#       Chevrolet Vectra 1994
#
#       Preços de R$ 11.451 a R$ 25.051
#
#       ## Deseja financiar um veículo?
#
#       Faça uma simulação de financiamento e veja as melhores condições para você.
#
#       Mulher com smartphone, carro e scooter azuis
#
#       ## Ofertas para Chevrolet Vectra 2011
#
#       Encontre o veículo incrível para você 🚙
#
#       Comprar
#
#       Vender
#
#       Serviços
#
#       Revendedor
#
#       Institucional
#
#       Aplicativos
#
#       © 2026 Mobiauto CNPJ: 32.158.029/0001-92
#
#       Todos os direitos reservados.
#
#       Uma empresa do
# DEBUG ======================== assistant =========================
# DEBUG O valor de um **GM Vectra 2011 automático** varia consideravelmente dependendo da versão (Expression,
#       Elegance, Elite ou Collection) e do estado de conservação do veículo.
#
#       De acordo com referências baseadas na Tabela FIPE, os valores estimados para as versões automáticas são:
#
#       *   **Vectra Expression 2.0 (Aut):** Aproximadamente **R$ 40.428**
#       *   **Vectra Elegance 2.0 (Aut):** Aproximadamente **R$ 41.006**
#       *   **Vectra Elite 2.0 (Aut):** Aproximadamente **R$ 43.061**
#       *   **Vectra Collection 2.0 (Aut):** Aproximadamente **R$ 45.491**
#
#       **Observações importantes:**
#       1.  **Estado do Veículo:** Carros com baixa quilometragem, histórico de revisões comprovado e pintura
#       impecável podem ser vendidos acima da FIPE.
#       2.  **Mercado Local:** Os preços podem variar conforme a região do Brasil e a demanda local.
#       3.  **Câmbio Automático:** Por ser um carro com certa idade, o estado de manutenção da transmissão automática
#       é um fator determinante no preço. Se o câmbio apresentar falhas, o valor cai drasticamente.
#
#       Para obter o valor exato e atualizado hoje, recomendo consultar o site oficial da **Tabela FIPE** ou
#       aplicativos de venda como WebMotors e OLX para ver por quanto modelos similares estão sendo anunciados na sua
#       cidade.
# DEBUG ************************  METRICS  *************************
# DEBUG * Tokens:                      input=2118, output=353, total=2471
# DEBUG * Duration:                    7.5042s
# DEBUG * Tokens per second:           47.0404 tokens/s
# DEBUG * Time to first token:         7.5042s
# DEBUG ************************  METRICS  *************************
# DEBUG ------------------- Ollama Response End --------------------
# DEBUG Added RunOutput to Agent Session
# DEBUG *** Agent Run End: 972f7427-a40c-4edb-8060-b76593ee3bf5 ****
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>

# %%
agent.print_response("Qual é a temperatura aqui em hortolandia agora ?")
# Out:
# DEBUG ************** Agent ID: civic-morse-325107b5 **************
# DEBUG Creating new AgentSession: bb61871b-ab02-4efa-87f8-5abc00b9cdf2
# DEBUG ** Agent Run Start: 360a5910-21c1-473a-8704-7d782e409771 ***
# DEBUG Processing tools for model
# DEBUG Added tool web_search_using_tavily from tavily_tools
# DEBUG Added tool get_current_stock_price from yfinance_tools
# DEBUG ------------------ Ollama Response Start -------------------
# DEBUG ----------------- Model: gemma4:31b-cloud ------------------
# DEBUG =========================== user ===========================
# DEBUG Qual é a temperatura aqui em hortolandia agora ?
# /home/greg/Documents/Estudos/AGNOS/.venv/lib/python3.13/site-packages/rich/live.py:260: UserWarning: install
# "ipywidgets" for Jupyter support
#   warnings.warn('install "ipywidgets" for Jupyter support')
# DEBUG ======================== assistant =========================
# DEBUG Tool Calls:
#         - ID: '2244dfb4-888e-4377-8586-2dd3f4fe2bfa'
#           Name: 'web_search_using_tavily'
#           Arguments: 'query: temperatura atual Hortolândia SP'
# DEBUG ************************  METRICS  *************************
# DEBUG * Tokens:                      input=211, output=27, total=238
# DEBUG * Duration:                    0.7833s
# DEBUG * Tokens per second:           34.4687 tokens/s
# DEBUG * Time to first token:         0.7833s
# DEBUG ************************  METRICS  *************************
# DEBUG Running: web_search_using_tavily(query=...)
# DEBUG =========================== tool ===========================
# DEBUG Tool call Id: 2244dfb4-888e-4377-8586-2dd3f4fe2bfa
# DEBUG # temperatura atual Hortolândia SP
#
#       ### Summary
#       The current temperature in Hortolândia, SP is 20°C, with a forecast of showers and increasing humidity. The
#       maximum temperature today is expected to reach 31°C. The weather will remain partly cloudy with occasional
#       rain.
#
#       ### [Previsão do tempo para hoje em Hortolândia -
#       SP](https://tempoagora.uol.com.br/previsao-do-tempo/cidade/2186/hortolandia-sp)
#       A sensação térmica hoje pode chegar até 25°C durante o dia de hoje, levando em consideração os valores de
#       temperatura e umidade relativa do ar. O menor valor será de 20°C.
#
#       Projeção aponta queda de 9,4% na safra 2024/25 de cana
#
#       Projeção aponta queda de 9,4% na safra 2024/25 de cana
#
#       Intensificação das chuvas reduz queimadas em outubro
#
#
#
#       Risco de temporal na Grande SP
#
#       Ciclone extratropical se forma esta semana entre o RS e Uruguai
#
#
#
#       Espírito Santo segue em alerta para temporais e mais chuva
#
#       Pancadas de chuva e ciclone extratropical fecham outubro
#
#       + mais notícias [...] Baixo
#        Raios UV
#
#         Extrema
#        Ressecamento de pele
#
#         Atenção
#
#       Registrados hoje
#
#       Atualizado ás 23:5323:53
#
#        0 raios
#
#         Powered by SMAC
#        0 focos de queimadas
#
#         Powered by Agroclima PRO
#        Nevoeiro
#
#         Nenhum
#
#       ## Notícias e Previsão do tempo em Hortolndia - SP
#
#
#
#         Aeroporto Internacional de Viracopos, SP
#
#         20°
#
#         20°
#
#
#         Aeroporto de Jundiaí, SP
#
#         18°
#
#         18°
#
#
#         Aeroporto de São Roque, SP
#
#         17°
#
#         17°
#
#
#         Aeroporto do Campo de Marte, SP
#
#         19°
#
#         19°
#
#
#         Aeroporto Campo Fontenelle, SP
#
#         22°
#
#         22°
#
#
#
#         Sumaré, SP
#
#         20°
#
#         20°
#
#
#         Nova Odessa, SP
#
#         20°
#
#         20°
#
#
#         Paulínia, SP
#
#         20°
#
#         20°
#
#
#         Monte Mor, SP
#
#         20°
#
#         20°
#
#
#         Campinas, SP
#
#         20°
#
#         20°
#
#       Sim, a previsão é de 5 mm de chuva com 48% de possibilidade em Hortolndia - SP. [...] Noite com chuva e
#       trovoadas
#
#       Madrugada
#
#       Sol com muitas nuvens
#
#       Manhã
#
#       Sol com muitas nuvens
#
#       Tarde
#
#       Noite com chuva
#
#       Noite
#
#        Temperatura
#
#         Temperatura mínima 20° Temperatura máxima 30°
#        Chuva
#
#            5mm - 48%
#        Vento
#
#         NNE - 4km/h
#        Umidade
#
#         Úmidade mínima 60% Úmidade máxima 96%
#        Sol  06:27:02h 17:45:32h
#
#       Temperatura Celsius (Cº)
#
#       Não há previsão de chuva para o dia
#
#        TemperaturaTemp.
#        Chuva
#        Vento
#        Umidade
#
#       Índices de saúde
#
#       Atualizado ás 11:5323:53
#
#        Previsão de qualidade do ar
#
#         Satisfatório
#        Gripe e resfriado
#
#         Risco baixo
#        Mosquitos
#
#         Baixo
#        Raios UV
#
#         Extrema
#        Ressecamento de pele
#
#         Atenção
#
#       Índices de saúde
#
#       Atualizado ás 11:5323:53
#
#        Previsão de qualidade do ar
#
#         Satisfatório
#        Gripe e resfriado
#
#         Risco baixo
#        Mosquitos
#
#         Baixo
#        Raios UV
#
#         Extrema
#        Ressecamento de pele
# DEBUG ======================== assistant =========================
# DEBUG A temperatura atual em Hortolândia, SP, é de aproximadamente **20°C**.
#
#       A previsão para hoje indica que a temperatura máxima pode chegar aos **31°C**, com possibilidade de chuva e
#       trovoadas durante a noite.
# DEBUG ************************  METRICS  *************************
# DEBUG * Tokens:                      input=1145, output=56, total=1201
# DEBUG * Duration:                    1.3206s
# DEBUG * Tokens per second:           42.4058 tokens/s
# DEBUG * Time to first token:         1.3206s
# DEBUG ************************  METRICS  *************************
# DEBUG ------------------- Ollama Response End --------------------
# DEBUG Added RunOutput to Agent Session
# DEBUG *** Agent Run End: 360a5910-21c1-473a-8704-7d782e409771 ****
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
