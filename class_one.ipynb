# %%
from agno.models.groq import Groq
from agno.models.message import Message
from dotenv import load_dotenv

# %%
load_dotenv()
# Out:
# True

# %%
llm = Groq()
user_message = Message(role="user", content="Olá, meu nome é Fulano da Silva.")
assistant_message = Message(role="assistant", content="")

# %%
response = llm.invoke(
    messages=[user_message],
    assistant_message=assistant_message)

print(response.content)
# Out:
# Olá, Fulano! É um prazer conhecê-lo. Como posso ajudá-lo hoje? Quer conversar sobre algo em particular ou apenas bater um papo? Estou aqui para ajudar e responder às suas perguntas.
