# %%
from agno.models.groq import Groq
from agno.models.message import Message
from dotenv import load_dotenv

# %%
load_dotenv()
# Out:
# True

# %%
llm = Groq()
user_message = Message(role="user", content="Olá, meu nome é Fulano da Silva.")
assistant_message = Message(role="assistant", content="")

# %%
response = llm.invoke(
    messages=[user_message],
    assistant_message=assistant_message)

print(response.content)
# Out:
# Olá, prazer em conhecer você, Fulano da Silva! É um nome muito brasileiro e tradicional. Como posso ajudá-lo hoje? Você tem alguma dúvida, precisa de informações ou apenas quer conversar? Estou aqui para ajudar!
